# %% [markdown]
# # PANDAS

# %% [markdown]
#  Cho tập dataset
# facial expression recognition challenge dataset (fer2013.csv)
#
# https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge
#
# 1. Hãy in ra số dòng của tập dữ liệu.
# 2. Vẽ biểu đồ thể hiện số lượng dữ liệu của các lớp
# 3. Vẽ ảnh của 7 dữ liệu đầu tiên
# 4. Vẽ ảnh của 7 dữ liệu cuối cùng
# 5. Vẽ ảnh của 7 dữ liệu lớp 0 đầu tiên
# 6. Vẽ ảnh của 7 dữ liệu lớp 1 ngẫu nhiên
